# %%
# importing csv module
import csv

# csv file name
filename = "data example.csv"

filas  = []

with open(filename, "r") as archivo:
    lecturaCsv = csv.reader(archivo)
    
    for row in lecturaCsv:
        filas.append(row)
        
    #Obtener el numero de columnas
    print("Total no. of rows: %d"%(lecturaCsv.line_num))
    
    
FilasOrdenadas = sorted(filas)

#for i in FilasOrdenadas:
#    print(i)

import numpy as np

:datos = np.array(FilasOrdenadas)

x = datos[:, 0]
y = datos[:, 1]
xy = []
x2 = []
# Out:
#   Cell In[30], line 26
#     :datos = np.array(FilasOrdenadas)
#     ^
# SyntaxError: invalid syntax

# %%
# #importar el modulo para leer el archivoi
import csv
import datetime

def converDate2Unix(dateString):
    date_format = datetime.datetime.strptime(dateString, "%d/%m/%Y")
    return datetime.datetime.timestamp(date_format)


rutaArchivo = "tabla datos-.csv"
filas = []
filtroDatos = []


#Abrir archivo
with open(rutaArchivo, "r") as archivo:
    lecturaCsv = csv.reader(archivo)
    
    for fila in lecturaCsv:
        t, x, y  = fila[0], fila[1], fila [6]
        filtroDatos.append([t, y , x])
        
    #Para saber cuantos datos
    print( f"Datos en todo el documento {lecturaCsv.line_num}")


    
filtroPorSubgrupos = sorted(filtroDatos)

##Libreria para tratamiento de datos
import numpy as np
import matplotlib.pyplot as plt


dataIn =[]

x = []
y = []

for i in filtroPorSubgrupos:  
    
    if i[1] == "1":
        i[2] = int(i[2])
        dataIn.append(i)

        #x.append(i[0])
        #y.append(i[1])
 

#organizar por fechas
dataIn=sorted(dataIn)

#Convertimos a numpy para que funcione mejor todo en el datos
dataIn = np.array(dataIn)
#Convertir Cada dato de la tabla de datos en numeros enteros y fechas a unix


for x in range(len(dataIn)):
    for
    
(list(map(converDate2Unix, dataIn[:, 0])), list(map(int, dataIn[:, 2])))


for i in dataOut:
    print(dataOut)

#x = np.array(x)
#y = np.array(y)



#for i in x:
#    print(i)



#sumatoriaX = x.sum()

#print(sumatoriaX)
#print(dataIn)
#plt.plot(dataIn[:, 0], dataIn[:, 2])



#plt.plot(dataIn[1])
#plt.ylabel("Beneficios")
#plt.xlabel("tiempo")
#plt.show()
